# %% [markdown]
# **EXERCICE 1 :** Visualisation d’un nuage de points et exploration des
# variables

# %%
import pandas as pd
import seaborn as sns
import matplotlib as mp
import matplotlib.pyplot as plt
import numpy as np

print("lib loaded")
# Out:
# lib loaded

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
root_path = 'gdrive/My Drive/Colab Notebooks/'
dataset = pd.read_csv(root_path+"/data/house_pricing.csv", sep=",")
print("dataset loaded")
# Out:
# dataset loaded

# %%
dataset.head(10)
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
# 5   6          50       RL  ...        WD         Normal    143000
# 6   7          20       RL  ...        WD         Normal    307000
# 7   8          60       RL  ...        WD         Normal    200000
# 8   9          50       RM  ...        WD        Abnorml    129900
# 9  10         190       RL  ...        WD         Normal    118000
#
# [10 rows x 81 columns]

# %%
for col in dataset.columns:
  print(dataset[col])
  print("---------------------")
# Out:
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
#         ...
# 1455    1456
# 1456    1457
# 1457    1458
# 1458    1459
# 1459    1460
# Name: Id, Length: 1460, dtype: int64
# ---------------------
# 0       60
# 1       20
# 2       60
# 3       70
# 4       60
#         ..
# 1455    60
# 1456    20
# 1457    70
# 1458    20
# 1459    20
# Name: MSSubClass, Length: 1460, dtype: int64
# ---------------------
# 0       RL
# 1       RL
# 2       RL
# 3       RL
# 4       RL
#         ..
# 1455    RL
# 1456    RL
# 1457    RL
# 1458    RL
# 1459    RL
# Name: MSZoning, Length: 1460, dtype: object
# ---------------------
# 0       65.0
# 1       80.0
# 2       68.0
# 3       60.0
# 4       84.0
#         ...
# 1455    62.0
# 1456    85.0
# 1457    66.0
# 1458    68.0
# 1459    75.0
# Name: LotFrontage, Length: 1460, dtype: float64
# ---------------------
# 0        8450
# 1        9600
# 2       11250
# 3        9550
# 4       14260
#         ...
# ...

# %%
df1 = dataset[['LotArea', 'SalePrice']]
df1.plot(x="LotArea",y="SalePrice", kind="scatter")

# %%
sns.pairplot(df1)

# %%
aff1 = df1[(df1["LotArea"]<20000) & (df1["SalePrice"]<500000)]
aff1
# Out:
#       LotArea  SalePrice
# 0        8450     208500
# 1        9600     181500
# 2       11250     223500
# 3        9550     140000
# 4       14260     250000
# ...       ...        ...
# 1455     7917     175000
# 1456    13175     210000
# 1457     9042     266500
# 1458     9717     142125
# 1459     9937     147500
#
# [1401 rows x 2 columns]

# %%
df2 = dataset[['LotFrontage', 'LotArea']]
df2.plot(x="LotFrontage",y="LotArea", kind="scatter")

# %%
sns.pairplot(df2)
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
aff2 = df2[(df2["LotFrontage"]<200) & (df2["LotArea"]<100000)]
aff2
# Out:
#       LotFrontage  LotArea
# 0            65.0     8450
# 1            80.0     9600
# 2            68.0    11250
# 3            60.0     9550
# 4            84.0    14260
# ...           ...      ...
# 1455         62.0     7917
# 1456         85.0    13175
# 1457         66.0     9042
# 1458         68.0     9717
# 1459         75.0     9937
#
# [1198 rows x 2 columns]
