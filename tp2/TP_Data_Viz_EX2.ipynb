# %% [markdown]
# **EXERCICE 2 :** Visualisation de relations continues

# %%
import pandas as pd
import seaborn as sns
import matplotlib as mp
import matplotlib.pyplot as plt
import numpy as np

print("lib loaded")
# Out:
# lib loaded

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
root_path = 'gdrive/My Drive/Colab Notebooks/'
dataset = pd.read_csv(root_path+"/data/sales_predictions.csv", sep=",")
print("dataset loaded")
# Out:
# dataset loaded

# %%
dataset.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %%
df3 = dataset[['item_price', 'date']]
graph = sns.relplot(x='item_price', y='date', ci=None, data=df3)

# %%
graph = sns.relplot(x='item_price', y='date', ci=None, data=df3.sample(50))

# %%
plt.figure(figsize=(20,6))
graph = sns.relplot(x='item_price', y='date', ci=None, data=df3.sample(50))

# %%
df3['date'] = pd.to_datetime(df3['date'])
df3['date']
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0         2013-02-01
# 1         2013-03-01
# 2         2013-05-01
# 3         2013-06-01
# 4         2013-01-15
#              ...
# 2935844   2015-10-10
# 2935845   2015-09-10
# 2935846   2015-10-14
# 2935847   2015-10-22
# 2935848   2015-03-10
# Name: date, Length: 2935849, dtype: datetime64[ns]

# %%
plt.figure(figsize=(20,6))
graph = sns.relplot(x='date', y='item_price', ci=None, data=df3.sample(50))
