# %%
import pandas as pd
from pyspark import *
from pyspark.sql import *
from pyspark.sql.functions import *
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### Charger la donnée bateaux.parq dans une DataFrame

# %%
df = pd.read_parquet("/dbfs/FileStore/tables/bateaux.parq")
print("Dataset loaded")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Dataset loaded
# </div>

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id_vessel</th>
#       <th>mmsi</th>
#       <th>type</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>timestamp_pos</th>
#       <th>speed</th>
#       <th>heading</th>
#       <th>payload</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>4440</td>
#       <td>0</td>
#       <td>35.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>1416006922000</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>b'\\s:rORBCOMM999,q:u,c:1416006922*3B\\!AIVDM,...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>121165</td>
#       <td>412417168</td>
#       <td>30.0</td>
#       <td>28.596467</td>
#       <td>122.416040</td>
#       <td>1416009251000</td>
#       <td>7.8</td>
#       <td>NaN</td>
#       <td>b'\\s:rORBCOMM000,q:u,c:1416009251*32\\!AIVDM,...</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>124436</td>
#       <td>412688540</td>
#       <td>38.0</td>
#       <td>39.015320</td>
#       <td>121.707040</td>
#       <td>1416009253000</td>
#       <td>0.0</td>
#       <td>NaN</td>
#       <td>b'\\s:rORBCOMM000,q:u,c:1416009253*30\\!AIVDM,...</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>123311</td>
#       <td>563610000</td>
#       <td>70.0</td>
#       <td>49.083427</td>
#       <td>-123.345925</td>
#       <td>1416009253000</td>
#       <td>13.3</td>
#       <td>209.0</td>
#       <td>b'\\s:rORBCOMM000,q:u,c:1416009253*30\\!AIVDM,...</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>63048</td>
#       <td>413807776</td>
#       <td>70.0</td>
#       <td>22.217245</td>
#       <td>114.327442</td>
#       <td>1416009253000</td>
#       <td>5.6</td>
#       <td>NaN</td>
#       <td>b'\\s:rORBCOMM000,q:u,c:1416009253*30\\!AIVDM,...</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### Afficher le nombre d'éléments du DF

# %%
print("Number of elements = ", df.size)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Number of elements =  2834487
# </div>

# %% [markdown]
# #### Afficher le type des éléments du DF

# %%
print(df.dtypes)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">id_vessel          int64
# mmsi               int64
# type             float64
# lat              float64
# lon              float64
# timestamp_pos      int64
# speed            float64
# heading          float64
# payload           object
# dtype: object
# </div>

# %% [markdown]
# #### Afficher le schéma du DF

# %%
sc = SparkContext("local", "app")

spark = SparkSession.builder.getOrCreate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">ValueError</span>                                Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-4054925785145073&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>sc <span class="ansi-blue-fg">=</span> SparkContext<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;local&#34;</span><span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">&#34;app&#34;</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      2</span>
# <span class="ansi-green-intense-fg ansi-bold">      3</span> spark <span class="ansi-blue-fg">=</span> SparkSession<span class="ansi-blue-fg">.</span>builder<span class="ansi-blue-fg">.</span>getOrCreate<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/context.py</span> in <span class="ansi-cyan-fg">__init__</span><span class="ansi-blue-fg">(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls)</span>
# <span class="ansi-green-intense-fg ansi-bold">    131</span>                     &#34; note this option will be removed in Spark 3.0&#34;)
# <span class="ansi-green-intense-fg ansi-bold">    132</span>
# <span class="ansi-green-fg">--&gt; 133</span><span class="ansi-red-fg">         </span>SparkContext<span class="ansi-blue-fg">.</span>_ensure_initialized<span class="ansi-blue-fg">(</span>self<span class="ansi-blue-fg">,</span> gateway<span class="ansi-blue-fg">=</span>gateway<span class="ansi-blue-fg">,</span> conf<span class="ansi-blue-fg">=</span>conf<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    134</span>         <span class="ansi-green-fg">try</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    135</span>             self._do_init(master, appName, sparkHome, pyFiles, environment, batchSize, serializer,
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/context.py</span> in <span class="ansi-cyan-fg">_ensure_initialized</span><span class="ansi-blue-fg">(cls, instance, gateway, conf)</span>
# <span class="ansi-green-intense-fg ansi-bold">    335</span>                         <span class="ansi-blue-fg">&#34; created by %s at %s:%s &#34;</span>
# <span class="ansi-green-intense-fg ansi-bold">    336</span>                         % (currentAppName, currentMaster,
# <span class="ansi-green-fg">--&gt; 337</span><span class="ansi-red-fg">                             callsite.function, callsite.file, callsite.linenum))
# </span><span class="ansi-green-intense-fg ansi-bold">    338</span>                 <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    339</span>                     SparkContext<span class="ansi-blue-fg">.</span>_active_spark_context <span class="ansi-blue-fg">=</span> instance
#
# <span class="ansi-red-fg">ValueError</span>: Cannot run multiple SparkContexts at once; existing SparkContext(app=Databricks Shell, master=local[8]) created by __init__ at /local_disk0/tmp/1579638786642-0/PythonShell.py:1163 </div>

# %%
dfSpark = spark.createDataFrame(df)
dfSpark.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+---------+----+------------------+-------------------+-------------+-----+-------+--------------------+
# id_vessel|     mmsi|type|               lat|                lon|timestamp_pos|speed|heading|             payload|
# +---------+---------+----+------------------+-------------------+-------------+-----+-------+--------------------+
#      4440|        0|35.0|              null|               null|1416006922000| null|   null|[5C 73 3A 72 4F 5...|
#    121165|412417168|30.0|28.596466666666668|          122.41604|1416009251000|  7.8|   null|[5C 73 3A 72 4F 5...|
#    124436|412688540|38.0|          39.01532|          121.70704|1416009253000|  0.0|   null|[5C 73 3A 72 4F 5...|
#    123311|563610000|70.0| 49.08342666666667|        -123.345925|1416009253000| 13.3|  209.0|[5C 73 3A 72 4F 5...|
#     63048|413807776|70.0|         22.217245| 114.32744166666667|1416009253000|  5.6|   null|[5C 73 3A 72 4F 5...|
#     60202|244690585|51.0| 52.18333833333333|  4.996126666666667|1416009251000|  0.0|   null|[5C 73 3A 72 4F 5...|
#     18884|412464280|52.0|22.565291666666667|         114.273425|1416009253000|  3.8|  268.0|[5C 73 3A 72 4F 5...|
#      6899|244710042|80.0|          51.81129|           4.611525|1416009253000|  0.0|   null|[5C 73 3A 72 4F 5...|
#     65727|636016121|80.0|           12.4185|         -70.130165|1416009253000|  0.0|   93.0|[5C 73 3A 72 4F 5...|
#     33529|258310000|89.0| 63.43951166666667| 10.350478333333333|1416009251000|  0.0|  353.0|[5C 73 3A 72 4F 5...|
#     35619|228284800|52.0|          49.47528|           0.132895|1416009253000|  0.0|  278.0|[5C 73 3A 72 4F 5...|
#     41040|636091848|71.0|27.900001666666668|-13.668798333333333|1416009253000| 16.3|  225.0|[5C 73 3A 72 4F 5...|
#    113862|412565686|30.0| 39.71163166666667|          119.82036|1416009253000|  0.0|   null|[5C 73 3A 72 4F 5...|
#      6912|357361000|70.0|31.990001666666668|          120.63421|1416009251000|  0.1|  277.0|[5C 73 3A 72 4F 5...|
#    103343|432620000|70.0|-3.715298333333333|           114.4597|1416006921000|  0.0|   21.0|[5C 73 3A 72 4F 5...|
#     27883|211494070|80.0|          51.83454|            4.48183|1416009253000|  7.7|   null|[5C 73 3A 72 4F 5...|
#     12186|432876000|70.0|         36.966695| -76.42965166666667|1416009253000|  0.0|   42.0|[5C 73 3A 72 4F 5...|
#    184842|352841000|89.0| 42.56032666666667| 141.71708166666667|1416009251000|  3.1|  310.0|[5C 73 3A 72 4F 5...|
#     31003|244690618|79.0|          51.86452|  6.063571666666666|1416009253000|  0.0|   null|[5C 73 3A 72 4F 5...|
#     31003|244690618|79.0|          51.86452|  6.063571666666666|1416009253000|  0.0|   null|[5C 73 3A 72 4F 5...|
# +---------+---------+----+------------------+-------------------+-------------+-----+-------+--------------------+
# only showing top 20 rows
#
# </div>

# %%
dfSpark.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- id_vessel: long (nullable = true)
# -- mmsi: long (nullable = true)
# -- type: double (nullable = true)
# -- lat: double (nullable = true)
# -- lon: double (nullable = true)
# -- timestamp_pos: long (nullable = true)
# -- speed: double (nullable = true)
# -- heading: double (nullable = true)
# -- payload: binary (nullable = true)
#
# </div>

# %% [markdown]
# #### Ordonnez les bateaux par vitesse

# %%
dfSpark.createOrReplaceTempView("bateaux")
dfSpark = spark.sql("SELECT * FROM bateaux WHERE speed IS NOT NULL")
display(dfSpark)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id_vessel</th><th>mmsi</th><th>type</th><th>lat</th><th>lon</th><th>timestamp_pos</th><th>speed</th><th>heading</th><th>payload</th></tr></thead><tbody><tr><td>121165</td><td>412417168</td><td>30.0</td><td>28.596466666666668</td><td>122.41604</td><td>1416009251000</td><td>7.8</td><td>null</td><td>XHM6ck9SQkNPTU0wMDAscTp1LGM6MTQxNjAwOTI1MSozMlwhQUlWRE0sMSwxLCxBLEI2OUN0VDAwQ1I8NjE8NDVrZ1A4R3dyNFNQMDAsMCowRQo=</td></tr><tr><td>124436</td><td>412688540</td><td>38.0</td><td>39.01532</td><td>121.70704</td><td>1416009253000</td><td>0.0</td><td>null</td><td>XHM6ck9SQkNPTU0wMDAscTp1LGM6MTQxNjAwOTI1MyozMFwhQUlWRE0sMSwxLCxBLDE2OVRQVzAzaDBgZThHMEZEajowMD93cDAwMDAsMCozMAo=</td></tr><tr><td>123311</td><td>563610000</td><td>70.0</td><td>49.08342666666667</td><td>-123.345925</td><td>1416009253000</td><td>13.3</td><td>209.0</td><td>XHM6ck9SQkNPTU0wMDAscTp1LGM6MTQxNjAwOTI1MyozMFwhQUlWRE0sMSwxLCxCLDE4SVAxVDUwMjVvO0dPcEw1T0I4PjZSRDBINWYsMCowNwo=</td></tr><tr><td>63048</td><td>413807776</td><td>70.0</td><td>22.217245</td><td>114.32744166666667</td><td>1416009253000</td><td>5.6</td><td>null</td><td>XHM6ck9SQkNPTU0wMDAscTp1LGM6MTQxNjAwOTI1MyozMFwhQUlWRE0sMSwxLCxBLDE2OmBsYDBQMHA4O0ZHUjxlV2JqVj92RjJMMmssMCo3Rgo=</td></tr><tr><td>60202</td><td>244690585</td><td>51.0</td><td>52.18333833333333</td><td>4.996126666666667</td><td>1416009251000</td><td>0.0</td><td>null</td><td>XHM6ck9SQkNPTU0wMDAscTp1LGM6MTQxNjAwOTI1MSozMlwhQUlWRE0sMSwxLCxBLDEzYUZmVkBQMDBQRm9lSE1vMGRoMD92MDI+YDwsMCo3MAo=</td></tr><tr><td>18884</td><td>412464280</td><td>52.0</td><td>22.565291666666667</td><td>114.273425</td><td>1416009253000</td><td>3.8</td><td>268.0</td><td>XHM6ck9SQkNPTU0wMDAscTp1LGM6MTQxNjAwOTI1MyozMFwhQUlWRE0sMSwxLCxBLDE2OUZsVjAwMFZgOzZSZjxyR0l0T0hJcDAwMDAsMCo1MQo=</td></tr><tr><td>6899</td><td>244710042</td><td>80.0</td><td>51.81129</td><td>4.611525</td><td>1416009253000</td><td>0.0</td><td>null</td><td>XHM6ck9SQkNPTU0wMDAscTp1LGM6MTQxNjAwOTI1MyozMFwhQUlWRE0sMSwxLCxCLDEzYUdyVlBQMDBQRTcyNk1hSGVQMD92RjI8N3UsMCoyMQo=</td></tr><tr><td>65727</td><td>636016121</td><td>80.0</td><td>12.4185</td><td>-70.130165</td><td>1416009253000</td><td>0.0</td><td>93.0</td><td>XHM6ck9SQkNPTU0wMDAscTp1LGM6MTQxNjAwOTI1MyozMFwhQUlWRE0sMSwxLCxCLDM5TlNFdkExaDBKdnYzSDc2aW8yYjJyQjBQMDAsMCoyRAo=</td></tr><tr><td>33529</td><td>258310000</td><td>89.0</td><td>63.43951166666667</td><td>10.350478333333333</td><td>1416009251000</td><td>0.0</td><td>353.0</td><td>XHM6ck9SQkNPTU0wMDAscTp1LGM6MTQxNjAwOTI1MSozMlwhQUlWRE0sMSwxLCxBLDMzbkV3TDUwMDBQZ0hHTlRDPkZ0aWMyPjgwMDAsMCo1MAo=</td></tr><tr><td>35619</td><td>228284800</td><td>52.0</td><td>49.47528</td><td>0.132895</td><td>1416009253000</td><td>0.0</td><td>278.0</td><td>XHM6ck9SQkNPTU0wMDAscTp1LGM6MTQxNjAwOTI1MyozMFwhQUlWRE0sMSwxLC
9</td><td>0.0</td><td>null</td><td>XHM6ck9SQkNPTU0wMDAscTp1LGM6MTQxNjAwOTI1MyozMFwhQUlWRE0sMSwxLCxCLDMzYUZmZlFQMDBQS2hLdk1jRU4xME92RFJFOzosMCowMgo=</td><td>null</td></tr><tr><td>64297</td><td>413550740</td><td>70.0</td><td>23.524813333333334</td><td>116.36594833333334</td><td>1.416009251E9</td><td>0.0</td><td>77.0</td><td>XHM6ck9SQkNPTU0wMDAscTp1LGM6MTQxNjAwOTI1MSozMlwhQUlWRE0sMSwxLCxCLDE2Okk4VTAwMDA4RGNVUj1NUEI+MWpLTDI+QDwsMCo1NAo=</td><td>null</td></tr><tr><td>148149</td><td>238988810</td><td>30.0</td><td>45.08321333333333</td><td>14.371665</td><td>1.416009251E9</td><td>0.0</td><td>null</td><td>XHM6ck9SQkNPTU0wMDAscTp1LGM6MTQxNjAwOTI1MSozMlwhQUlWRE0sMSwxLCxCLDEzU3JmMldQMDBRMWpMZklqd2o+ND92QjI+QDwsMCozQQo=</td><td>null</td></tr><tr><td>142221</td><td>525021043</td><td>70.0</td><td>-7.176266666666667</td><td>1 ...

# %% [markdown]
# #### Il est possible de créer un nouveau dataframe contenant des statistiques sur un dataframe

# %%
display(dfSpark.describe())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>id_vessel</th><th>mmsi</th><th>type</th><th>lat</th><th>lon</th><th>timestamp_pos</th><th>speed</th><th>heading</th></tr></thead><tbody><tr><td>count</td><td>313477</td><td>313477</td><td>304857</td><td>313469</td><td>313469</td><td>313477</td><td>313477</td><td>164911</td></tr><tr><td>mean</td><td>83974.32759979201</td><td>3.708824841372158E8</td><td>62.16769173743755</td><td>31.65608352477684</td><td>43.7823913234376</td><td>1.4160077662448218E9</td><td>2.968054115612944</td><td>175.76680148686262</td></tr><tr><td>stddev</td><td>104789.69093069504</td><td>1.2900045917442387E8</td><td>21.42375669262152</td><td>22.64862714636255</td><td>78.36199118240594</td><td>1034.0166722803676</td><td>5.251255455795128</td><td>106.89716517594576</td></tr><tr><td>min</td><td>1</td><td>0</td><td>1.0</td><td>-88.799435</td><td>-179.97899833333332</td><td>1.416006001E9</td><td>0.0</td><td>0.0</td></tr><tr><td>max</td><td>1454230</td><td>1063852744</td><td>255.0</td><td>86.93066166666667</td><td>179.9999</td><td>1.416009E9</td><td>102.0</td><td>359.0</td></tr></tbody></table></div>

# %% [markdown]
# #### Filtrer le dataframe bateaux sur un bateau en particulier

# %%
dfSpark.createOrReplaceTempView("bateaux")
display(spark.sql("SELECT * FROM bateaux WHERE id_vessel = 60202"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id_vessel</th><th>mmsi</th><th>type</th><th>lat</th><th>lon</th><th>timestamp_pos</th><th>speed</th><th>heading</th><th>payload</th><th>timestamp_readable</th></tr></thead><tbody><tr><td>60202</td><td>244690585</td><td>51.0</td><td>52.18333833333333</td><td>4.996126666666667</td><td>1.416009251E9</td><td>0.0</td><td>null</td><td>XHM6ck9SQkNPTU0wMDAscTp1LGM6MTQxNjAwOTI1MSozMlwhQUlWRE0sMSwxLCxBLDEzYUZmVkBQMDBQRm9lSE1vMGRoMD92MDI+YDwsMCo3MAo=</td><td>null</td></tr><tr><td>60202</td><td>244690585</td><td>51.0</td><td>52.18333833333333</td><td>4.996176666666667</td><td>1.416006797E9</td><td>0.0</td><td>null</td><td>XHM6ck9SQkNPTU0wMDAscTp1LGM6MTQxNjAwNjc5NyozMlwhQUlWRE0sMSwxLCxBLDEzYUZmVkBQMDBQRm9mRE1vMGRoMD92RDI+YDwsMCowQgo=</td><td>null</td></tr><tr><td>60202</td><td>244690585</td><td>51.0</td><td>52.18334</td><td>4.996126666666667</td><td>1.416008432E9</td><td>0.0</td><td>null</td><td>XHM6ck9SQkNPTU0wMDAscTp1LGM6MTQxNjAwODQzMiozMFwhQUlWRE0sMSwxLCxCLDEzYUZmVkBQMDBQRm9lSE1vMGU6Vz92cjI+QDwsMCoyNQo=</td><td>null</td></tr><tr><td>60202</td><td>244690585</td><td>51.0</td><td>52.18334</td><td>4.996126666666667</td><td>1.416008432E9</td><td>0.0</td><td>null</td><td>XHM6ck9SQkNPTU0wMDAscTp1LGM6MTQxNjAwODQzMiozMFwhQUlWRE0sMSwxLCxBLDEzYUZmVkBQMDBQRm9lSE1vMGU6Vz92cjI+QDwsMCoyNgo=</td><td>null</td></tr><tr><td>60202</td><td>244690585</td><td>51.0</td><td>52.18333166666667</td><td>4.996146666666666</td><td>1.416007523E9</td><td>0.0</td><td>null</td><td>XHM6ck9SQkNPTU0wMDAscTp1LGM6MTQxNjAwNzUyMyozRVwhQUlWRE0sMSwxLCxCLDEzYUZmVkBQMDBQRm9laE1vMGNoMD92YDI4PDUsMCo1Nwo=</td><td>null</td></tr><tr><td>60202</td><td>244690585</td><td>51.0</td><td>52.18333666666667</td><td>4.9961633333333335</td><td>1.416006054E9</td><td>0.0</td><td>null</td><td>XHM6ck9SQkNPTU0wMDAscTp1LGM6MTQxNjAwNjA1NCozQVwhQUlWRE0sMSwxLCxBLDEzYUZmVkBQMDBQRm9mNE1vMGRTaj93VjI+QDwsMCoyOQo=</td><td>null</td></tr></tbody></table></div>

# %% [markdown]
# #### Le nombre de bateaux qui ont été à l'arret et qui se sont déplacés

# %%
dfA = spark.sql("SELECT * FROM bateaux WHERE speed = 0").count()
print("Nombre de bateaux à l'arret = ", dfA)
dfD = spark.sql("SELECT * FROM bateaux WHERE heading > 0").count()
print("Nombre de bateaux déplacés = ", dfD)
print("Nombre de bateaux qui ont été à l'arret et qui se sont déplacés = ", dfA+dfD)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Nombre de bateaux à l&#39;arret =  161761
# Nombre de bateaux déplacés =  162416
# Nombre de bateaux qui ont été à l&#39;arret et qui se sont déplacés =  324177
# </div>

# %% [markdown]
# #### Les types distincts de bateaux

# %%
dfSpark.groupBy('type').count().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+-----+
#  type|count|
# +-----+-----+
# 170.0|   74|
# 184.0|    4|
# 169.0|    8|
# 160.0|   13|
#  70.0|94249|
#  67.0|  125|
#   8.0|  127|
# 168.0|    9|
#  69.0| 4551|
# 206.0|   10|
#   7.0|  152|
# 142.0|    3|
# 112.0|   37|
# 154.0|    6|
# 232.0|    1|
# 124.0|    4|
# 253.0|   32|
# 235.0|   12|
# 128.0|   25|
# 201.0|   12|
# +-----+-----+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# #### On affiche la moyenne de la vitesse des bateaux sans tenir compte des bateaux a l'arret

# %%
dfSA = spark.sql("SELECT * FROM bateaux WHERE speed != 0")
dfSA.select(avg(col("speed"))).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+
#        avg(speed)|
# +-----------------+
# 6.132620817843859|
# +-----------------+
#
# </div>

# %% [markdown]
# #### On affiche la date min puis  la date max pour chaque bateau

# %% [markdown]
# #### Créer un dataframe avec l'id, la vitesse et le timestamp readable

# %%
dfNew = spark.sql("SELECT id_vessel, speed, timestamp_readable FROM bateaux")
display(dfNew)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id_vessel</th><th>speed</th><th>timestamp_readable</th></tr></thead><tbody><tr><td>124436</td><td>0.0</td><td>null</td></tr><tr><td>60202</td><td>0.0</td><td>null</td></tr><tr><td>6899</td><td>0.0</td><td>null</td></tr><tr><td>65727</td><td>0.0</td><td>null</td></tr><tr><td>33529</td><td>0.0</td><td>null</td></tr><tr><td>35619</td><td>0.0</td><td>null</td></tr><tr><td>113862</td><td>0.0</td><td>null</td></tr><tr><td>103343</td><td>0.0</td><td>null</td></tr><tr><td>12186</td><td>0.0</td><td>null</td></tr><tr><td>31003</td><td>0
r><td>36331</td><td>0.0</td><td>null</td></tr><tr><td>45225</td><td>0.0</td><td>null</td></tr><tr><td>45225</td><td>0.0</td><td>null</td></tr><tr><td>103037</td><td>0.0</td><td>null</td></tr><tr><td>47278</td><td>0.0</td><td>null</td></tr><tr><td>3511</td><td>0.0</td><td>null</td></tr><tr><td>49947</td><td>0.0</td><td>null</td></tr><tr><td>85898</td><td>0.0</td><td>null</td></tr><tr><td>17752</td><td>0.0</td><td>null</td></tr><tr><td>22167</td><td>0.0</td><td>null</td></tr><tr><td>48440</td><td>0.0</td><td>null</td></tr><tr><td ...

# %% [markdown]
# #### Créer une colonne mois pour le mois en cours

# %%
dfNew = dfNew.withColumn("month", current_date())
dfNew = dfNew.withColumn("month", month(col("month")))
display(dfNew)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id_vessel</th><th>speed</th><th>timestamp_readable</th><th>month</th></tr></thead><tbody><tr><td>124436</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>60202</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>6899</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>65727</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>33529</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>35619</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>113862</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>103343</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>12186</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>31003</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>31003</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>64297</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>148149</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>142221</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>23149</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>27703</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>53694</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>56638</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>58267</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>120733</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>52275</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>206870</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>206870</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>30629</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>21834</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>67471</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>39758</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>109162</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>60251</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>112604</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>112604</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>10476</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>31039</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>2706</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>35222</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>17143</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>40609</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>191277</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>191277</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>81001</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>48699</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>207632</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>2863</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>6411</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>59299</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>70795</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>24413</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>40448</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>16208</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>4041</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>4041</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>125615</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>67287</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>6143</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>94096</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>60795</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>55296</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>50436</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>21609</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>26199</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>65991</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>4435</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>187644</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>16754</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>36410</td><td>0.0</td><td>null</td><td>1</td></tr><tr><td>15465< ...

# %% [markdown]
# #### Ajouter une colonne boolean à True si le bateau est en mouvement

# %%
from pyspark.sql.types import *

def moving(x):
  return x > 0
udf_moving = udf(moving,BooleanType())

dfNew = dfNew.withColumn("moving", udf_moving(dfNew.speed))
display(dfNew)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id_vessel</th><th>speed</th><th>timestamp_readable</th><th>month</th><th>moving</th></tr></thead><tbody><tr><td>124436</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>60202</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>6899</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>65727</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>33529</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>35619</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>113862</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>103343</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>12186</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>31003</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>31003</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>64297</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>148149</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>142221</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>23149</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>27703</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>53694</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>56638</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>58267</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>120733</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>52275</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>206870</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>206870</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>30629</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>21834</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>67471</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>39758</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>109162</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>60251</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>112604</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>112604</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>10476</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>31039</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>2706</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>35222</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>17143</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>40609</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>191277</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>191277</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>81001</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>48699</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>207632</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>2863</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>6411</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>59299</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>70795</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>24413</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>40448</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>16208</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>4041</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>4041</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>125615</td><td>0.0</td><td>null</td><td>1</td><td>false</td></tr><tr><td>67287</td><td>0. ...

# %% [markdown]
# #### Enregistrer la table

# %%
dfNew.write.parquet("/dbfs/FileStore/tables/bateaux_filtered.parq")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### Afficher par type, le nombre de bateaux, la vitesse max et la moyenne de la vitesse, ordonnés par nombre de bateaux (requete SQL)

# %%
display(spark.sql("SELECT COUNT(type), MAX(speed), AVG(speed) FROM bateaux GROUP BY type ORDER BY count(type) ASC"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count
td>9</td><td>6.7</td><td>1.3444444444444446</td></tr><tr><td>9</td><td>8.4</td><td>2.1333333333333337</td></tr><tr><td>10</td><td>4.3</td><td>1.21</td></tr><tr><td>10</td><td>9.4</td><td>2.56</td></tr><tr><td>10</td><td>0.0</td><td>0.0</td></tr><tr><td>10</td><td>0.0</td><td>0.0</td></tr><tr><td>10</td><td>0.2</td><td>0.05</td></tr><tr><td>10</td><td>0.0</td><td>0.0</td></tr><tr><td>10</td><td>9.5</td><td>4.630000000000001</td></tr><tr><td>10</td><td>7.9</td><td>5.25</td></tr><tr><td>10</td><td>0.0</td><td>0.0</td></tr><tr><td>10</td><td>0.0</td><td>0.0</td></tr><tr><td>11</td><td>0.1</td><td>0.009090909090909092</td></tr><tr><td>11</td><td>8.4</td><td>1.9272727272727275</td></tr><tr><td>11</td><td>0.2</td><td>0.07272727272727274</td></tr><tr><td>11</td><td>4.1</td><td>0.3727272727272727</td></tr><tr><td>11</td><td>8.2</td><td>2.190909090909091</td></tr><tr><td>11</td><td>0.1</td><td>0.009090909090909092</td></tr><tr><td>12</td><td>17.4</td><td>5.124999999999999</td></tr><tr><td>12</td><td>0.0</td><td>0.0</td></tr><tr><td>12</td><td>0.2</td><td>0.05833333333333334</td></tr><tr><td>12</td><td>7.3</td><td ...

# %% [markdown]
# ##### Mettons nos compétences au service d'un cas d'usage un peu plus intéressant.
# ##### Nous allons prendre un bateau de notre choix et nous allons tenter de calculer quels sont les bateaux qu'il a pu croiser sur sa route

# %% [markdown]
# #### Créer un nouveau dataframe basé sur le DF bateaux et filtré uniquement sur id_vessel de votre choix.
# #### Débarassez vous également de la colonne "payload" avec la méthode df.drop("colonne")

# %%
dfTest = spark.sql("SELECT * FROM bateaux WHERE id_vessel = 6899")
dfTest = dfTest.drop("payload")
display(dfTest)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id_vessel</th><th>mmsi</th><th>type</th><th>lat</th><th>lon</th><th>timestamp_pos</th><th>speed</th><th>heading</th><th>timestamp_readable</th></tr></thead><tbody><tr><td>6899</td><td>244710042</td><td>80.0</td><td>51.81129</td><td>4.611525</td><td>1.416009253E9</td><td>0.0</td><td>null</td><td>null</td></tr><tr><td>6899</td><td>244710042</td><td>80.0</td><td>51.81132</td><td>4.61159</td><td>1.416007796E9</td><td>0.0</td><td>null</td><td>null</td></tr><tr><td>6899</td><td>244710042</td><td>80.0</td><td>51.81134333333333</td><td>4.611483333333333</td><td>1.416006304E9</td><td>0.0</td><td>null</td><td>null</td></tr><tr><td>6899</td><td>244710042</td><td>80.0</td><td>51.811326666666666</td><td>4.611596666666666</td><td>1.416008526E9</td><td>0.0</td><td>null</td><td>null</td></tr><tr><td>6899</td><td>244710042</td><td>80.0</td><td>51.811296666666664</td><td>4.611576666666667</td><td>1.416007027E9</td><td>0.0</td><td>null</td><td>null</td></tr></tbody></table></div>

# %% [markdown]
# #### Créer un deuxième dataframe basé sur le DF bateaux, avec les colonnes id_vessel, lat, lon et timestamp_pos
# #### On transforme nos DF en rdd grâce à la fonction rdd

# %%
dfTest2 = spark.sql("SELECT id_vessel, lat, lon, timestamp_pos FROM bateaux")
display(dfTest2)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id_
><td>23.361016666666668</td><td>1.416009253E9</td></tr><tr><td>191277</td><td>31.773483333333335</td><td>120.91941666666666</td><td>1.416009253E9</td></tr><tr><td>191277</td><td>31.773483333333335</td><td>120.91941666666666</td><td>1.416009253E9</td></tr><tr><td>81001</td><td>36.90875</td><td>-76.326865</td><td>1.416009253E9</td></tr><tr><td>48699</td><td>29.986541666666668</td><td>122.005305</td><td>1.416009253E9</td></tr><tr><td>207632</td><td>26.1169</td><td>-80.10808166666666</td><td>1.416009253E9</td></tr><tr><td>2863</t ...

# %%
rdd1 = dfTest.rdd
rdd2 = dfTest2.rdd
print("Convertion done")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Convertion done
# </div>

# %% [markdown]
# #### On calcule le nombre d'enregistrements associés à notre bateau
#
# #### On calcule le nombre d'enregistrements du RDD de référence

# %%
print("Number of elements in RDD bateau -> %i" % (rdd1.count()))
print("Number of elements in RDD référentiel -> %i" % (rdd2.count()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Number of elements in RDD bateau -&gt; 5
# Number of elements in RDD référentiel -&gt; 313477
# </div>

# %% [markdown]
# ##### Créer un RDD batEtude produit cartesien de notre RDD bateau et du RDD référentiel

# %%
rddBatEtude = rdd1.cartesian(rdd2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ##### On affiche la première ligne pour analyser son contenu
# ##### Astuce : n'oubliez pas que l'on est maintenant sur des RDD

# %%
rddBatEtude.take(1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[92]: [(Row(id_vessel=6899, mmsi=244710042, type=80.0, lat=51.81129, lon=4.611525, timestamp_pos=&#39;1.416009253E9&#39;, speed=0.0, heading=None, timestamp_readable=None),
#   Row(id_vessel=124436, lat=39.01532, lon=121.70704, timestamp_pos=&#39;1.416009253E9&#39;))]</div>

# %% [markdown]
# ##### On pourrait s'amuser à compter le nombre de lignes totales du RDD.. mais c'est une action !
# ##### Il est possible que cela prenne un peu de temps selon la taille de votre RDD contenant un seul id_vessel

# %%
print("Number of rows in RDD Bat Etude -> %i" % (rddBatEtude.count()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Number of rows in RDD Bat Etude -&gt; 1567385
# </div>

# %% [markdown]
# ##### B4 - Filtrer notre produit cartésien pour éliminer les bateaux identiques à notre id_vessel choisi
# ##### Astuce : notre RDD batEtude est composé de tuples(bateau,bateauRef)

# %%
rddBatEtude = rddBatEtude.distinct()
print("Number of rows in RDD Bat Etude -> %i" % (rddBatEtude.count()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Number of rows in RDD Bat Etude -&gt; 1417005
# </div>

# %% [markdown]
# ##### On va également filtrer les informations des bateaux pour ne conserver que les enregistrements à +/- une heure (3600s)

# %%
rddFiltered =

# %%
def calculateDistanceInKilometer(userlat, userlon, otherlat, otherlon):
    AVERAGE_RADIUS_OF_EARTH_KM = 6371
    latDistance = math.radians(userlat - otherlat)
    lngDistance = math.radians(userlon - otherlon)
    sinLat = math.sin(latDistance / 2)
    sinLng = math.sin(lngDistance / 2)
    a = sinLat * sinLat + (math.cos(math.radians(userlat)) * math.cos(math.radians(otherlat))* sinLng * sinLng)
    c = 2 * math.atan2(math.sqrt(a), math.sqrt(1 - a))
    return int(AVERAGE_RADIUS_OF_EARTH_KM * c)

# %% [markdown]
# ##### Filtrer notre RDD en ne conservant que les bateaux pour lesquels la distance est inférieure à 1 km
# ##### La méthode calculateDistanceInKilometer(lat,lon,lat,long) renvoi la distance en kilomètres entre deux coordonnées

# %%
sc.stop()
spark.stop()
